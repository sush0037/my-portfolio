# %% [markdown]
# <a href="https://colab.research.google.com/github/sush0037/my-portfolio/blob/master/DeepLearningSessions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 27.6 MB/s eta 0:00:00
# ...

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download ('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# Bag of words >> count of words irrespective of order
# 1. vocabulary
# 2. Vector representation
# TF >> term frequency
# IDF >>
# sentiment analysis needed IDF and TF

# %%
import nltk
from nltk.corpus import movie_reviews  # orebuild data set
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.classify import NaiveBayesClassifier #classfier algorithm
from nltk.classify.util import accuracy
import random

# %%
nltk.download("movie_reviews")
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def extract_features(words):
  stop_words  = set(stopwords.words('english'))
  features = {}
  for word in words:
    if word not in stop_words:
      features[word] = True
  return features

# %%
reviews=[(list(movie_reviews.words(fileid)),category)
for category in movie_reviews.categories()
for fileid in movie_reviews.fileids(category)]

# %%
random.shuffle(reviews)

# %%
feature_sets = [(extract_features(review),category) for (review,category) in reviews]

# %%
train_size=int(len(feature_sets)*0.8)
train_set,test_set=feature_sets[:train_size],feature_sets[train_size:]

# %%
classifier=NaiveBayesClassifier.train(train_set)

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#                    sucks = True              neg : pos    =     15.1 : 1.0
#              outstanding = True              pos : neg    =     13.5 : 1.0
#                   avoids = True              pos : neg    =     12.8 : 1.0
#                insulting = True              neg : pos    =     12.5 : 1.0
#                strongest = True              pos : neg    =     11.4 : 1.0
#                   seagal = True              neg : pos    =     11.2 : 1.0
#              uninvolving = True              neg : pos    =     11.2 : 1.0
#                     slip = True              pos : neg    =     10.8 : 1.0
#               schumacher = True              neg : pos    =     10.6 : 1.0
#                stupidity = True              neg : pos    =     10.6 : 1.0

# %%
test_review="The movie was good"

# %%
def predict_sentiment(review):
  words=word_tokenize(review)
  features=extract_features(words)
  return classifier.classify(features)

# %%
test_review="The movie was too superb"
predict_sentiment(test_review)
# Out:
# 'pos'

# %%
test_review_new="The movie was not good"
predict_sentiment(test_review_new)
# Out:
# 'neg'

# %%
predict_sentiment(test_review_new)
# Out:
# 'neg'

# %%
test_review_new1="The movie was amazing"
predict_sentiment(test_review_new1)
# Out:
# 'pos'

# %% [markdown]
# NLP >> Sentiment analysis, NER, QnA, Lang transformation, summarization
# sentence tokenization
