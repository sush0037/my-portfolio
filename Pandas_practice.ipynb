# %% [markdown]
# <a href="https://colab.research.google.com/github/sush0037/my-portfolio/blob/master/Pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2 data structures- data series and data frame
#
#
#   Name  age
#  0 a      10
#  1 b      20
#  2 c      30

# %%
import pandas as pd
import numpy as np

# %%
ds=pd.Series()

# %%
ds
# Out:
# Series([], dtype: object)

# %%
#create a ds from a list
l=[1,2,3]
myser=pd.Series(l)

# %%
myser
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
myser[0]
# Out:
# np.int64(1)

# %%
myser[2]
# Out:
# np.int64(3)

# %%
l2=[10,20,30]
myser2=pd.Series(l2,index=['a','b','c'])

# %%
myser2
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
myser2["b"]
# Out:
# np.int64(20)

# %%
l=['a','b']
ds=pd.Series(l)

# %%
ds
# Out:
# 0    a
# 1    b
# dtype: object

# %%
s=pd.Series([10,20,30,40,50])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name="age"

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1028141915.py in <cell line: 0>()
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
s[2]
# Out:
# np.int64(30)

# %%
s[1:4]
# Out:
# 1    20
# 2    30
# 3    40
# Name: age, dtype: int64

# %%
# iloc-> location based indexing
s.iloc[3]
# Out:
# np.int64(40)

# %%
s.iloc[[1,3,4]]
# Out:
# 1    20
# 3    40
# 4    50
# Name: age, dtype: int64

# %%
index=["Carol","Alex","Simran","Bob","Tarun"]

# %%
s.index=index

# %%
s
# Out:
# Carol     10
# Alex      20
# Simran    30
# Bob       40
# Tarun     50
# Name: age, dtype: int64

# %%
s['Alex']
# Out:
# np.int64(20)

# %%
#loc-> label based indexing

# %%
s.loc[['Simran','Bob']]
# Out:
# Simran    30
# Bob       40
# Name: age, dtype: int64

# %%
s.iloc[2:4]
# Out:
# Simran    30
# Bob       40
# Name: age, dtype: int64

# %%
s
# Out:
# Carol     10
# Alex      20
# Simran    30
# Bob       40
# Tarun     50
# Name: age, dtype: int64

# %%
s.loc['Simran':'Tarun']
# Out:
# Simran    30
# Bob       40
# Tarun     50
# Name: age, dtype: int64

# %%
s
# Out:
# Carol     10
# Alex      20
# Simran    30
# Bob       40
# Tarun     50
# Name: age, dtype: int64

# %%
#filter
s[s>30]
# Out:
# Bob      40
# Tarun    50
# Name: age, dtype: int64

# %%
s["Bob"]=45

# %%
s
# Out:
# Carol     10
# Alex      20
# Simran    30
# Bob       45
# Tarun     50
# Name: age, dtype: int64

# %%
s["abc"]=55

# %%
s
# Out:
# Carol     10
# Alex      20
# Simran    30
# Bob       45
# Tarun     50
# abc       55
# Name: age, dtype: int64

# %% [markdown]
# DataFrame

# %%
#list
l=[1,2,3]
df1=pd.DataFrame(l)

# %%
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
#list of lists
data=[['a',10,'Blr'],['b',20,'Delhi'],['c',30,'Roorkee']]
df2=pd.DataFrame(data)

# %%
df2
# Out:
#    0   1        2
# 0  a  10      Blr
# 1  b  20    Delhi
# 2  c  30  Roorkee

# %%
df2=pd.DataFrame(data,columns=["name","age","city"],index=['a','b','c'])

# %%
df2
# Out:
#   name  age     city
# a    a   10      Blr
# b    b   20    Delhi
# c    c   30  Roorkee

# %%
df2['age']
# Out:
# a    10
# b    20
# c    30
# Name: age, dtype: int64

# %%
df2['age']=df2['age'].astype(float)

# %%
df2
# Out:
#   name   age     city
# a    a  10.0      Blr
# b    b  20.0    Delhi
# c    c  30.0  Roorkee

# %%
df2["age"]=df2["age"]+5

# %%
df2
# Out:
#   name   age     city
# a    a  20.0      Blr
# b    b  30.0    Delhi
# c    c  40.0  Roorkee

# %%
df2['age']=df2['age']+3

# %%
df2
# Out:
#   name   age     city
# a    a  23.0      Blr
# b    b  33.0    Delhi
# c    c  43.0  Roorkee

# %%
#add column last name
df2['last_name']=['A','B','C']

# %%
df2
# Out:
#   name   age     city last_name
# a    a  23.0      Blr         A
# b    b  33.0    Delhi         B
# c    c  43.0  Roorkee         C

# %%
df2['number']=pd.Series([1,2,3],index=['a','b','c'])

# %%
df2
# Out:
#   name   age     city last_name  number
# a    a  23.0      Blr         A       1
# b    b  33.0    Delhi         B       2
# c    c  43.0  Roorkee         C       3

# %%
df2['number2']=df2['age']+df2['number']

# %%
df2
# Out:
#   name   age     city last_name  number  number2
# a    a  23.0      Blr         A       1     24.0
# b    b  33.0    Delhi         B       2     35.0
# c    c  43.0  Roorkee         C       3     46.0

# %%
del df2['number2']

# %%
df2
# Out:
#   name   age     city last_name  number
# a    a  23.0      Blr         A       1
# b    b  33.0    Delhi         B       2
# c    c  43.0  Roorkee         C       3

# %%
data={
    "Name":['Alice','Bob','Carol','David','Eva','Alice'],
    "Age":[25,30,35,np.nan,29,25],
    "Department":['HR','IT','Finance','HR','IT','HR'],
    "Salary":[50000,60000,55000,70000,65000,50000]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Name   Age Department  Salary
# 0  Alice  25.0         HR   50000
# 1    Bob  30.0         IT   60000
# 2  Carol  35.0    Finance   55000
# 3  David   NaN         HR   70000
# 4    Eva  29.0         IT   65000
# 5  Alice  25.0         HR   50000

# %%
df.head(2)
# Out:
#     Name   Age Department  Salary
# 0  Alice  25.0         HR   50000
# 1    Bob  30.0         IT   60000

# %%
df.tail(3)
# Out:
#     Name   Age Department  Salary
# 3  David   NaN         HR   70000
# 4    Eva  29.0         IT   65000
# 5  Alice  25.0         HR   50000

# %%
df
# Out:
#     Name   Age Department  Salary
# 0  Alice  25.0         HR   50000
# 1    Bob  30.0         IT   60000
# 2  Carol  35.0    Finance   55000
# 3  David   NaN         HR   70000
# 4    Eva  29.0         IT   65000
# 5  Alice  25.0         HR   50000

# %%
#loc and iloc
df.iloc[1:3,:2]   #rows,columns
# Out:
#     Name   Age
# 1    Bob  30.0
# 2  Carol  35.0

# %%
df.loc[1:3,['Age','Department']]
# Out:
#     Age Department
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         HR

# %%
df.loc[1:3,'Name':'Department']
# Out:
#     Name   Age Department
# 1    Bob  30.0         IT
# 2  Carol  35.0    Finance
# 3  David   NaN         HR

# %%
df[["Age","Department"]]
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         HR
# 4  29.0         IT
# 5  25.0         HR

# %%
df.shape
# Out:
# (6, 4)

# %%
df
# Out:
#     Name   Age Department  Salary
# 0  Alice  25.0         HR   50000
# 1    Bob  30.0         IT   60000
# 2  Carol  35.0    Finance   55000
# 3  David   NaN         HR   70000
# 4    Eva  29.0         IT   65000
# 5  Alice  25.0         HR   50000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   Age         5 non-null      float64
#  2   Department  6 non-null      object
#  3   Salary      6 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   5.000000      6.000000
# mean   28.800000  58333.333333
# std     4.147288   8164.965809
# min    25.000000  50000.000000
# 25%    25.000000  51250.000000
# 50%    29.000000  57500.000000
# 75%    30.000000  63750.000000
# max    35.000000  70000.000000

# %%
df
# Out:
#     Name   Age Department  Salary
# 0  Alice  25.0         HR   50000
# 1    Bob  30.0         IT   60000
# 2  Carol  35.0    Finance   55000
# 3  David   NaN         HR   70000
# 4    Eva  29.0         IT   65000
# 5  Alice  25.0         HR   50000

# %%
df['Salary']=df['Salary']+5000

# %%
df
# Out:
#     Name   Age Department  Salary
# 0  Alice  25.0         HR   55000
# 1    Bob  30.0         IT   65000
# 2  Carol  35.0    Finance   60000
# 3  David   NaN         HR   75000
# 4    Eva  29.0         IT   70000
# 5  Alice  25.0         HR   55000

# %%
#rename column
df.rename(columns={"Department":"Dept"},inplace=True)

# %%
df
# Out:
#     Name   Age     Dept  Salary
# 0  Alice  25.0       HR   55000
# 1    Bob  30.0       IT   65000
# 2  Carol  35.0  Finance   60000
# 3  David   NaN       HR   75000
# 4    Eva  29.0       IT   70000
# 5  Alice  25.0       HR   55000

# %%
df['Dept'].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %%
df['Dept'].value_counts()
# Out:
# Dept
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
#data cleaning
df.isnull().sum()
# Out:
# Name      0
# Age       1
# Dept      0
# Salary    0
# dtype: int64

# %%
df.dropna(how="any")
# Out:
#     Name   Age     Dept  Salary
# 0  Alice  25.0       HR   55000
# 1    Bob  30.0       IT   65000
# 2  Carol  35.0  Finance   60000
# 4    Eva  29.0       IT   70000
# 5  Alice  25.0       HR   55000

# %%
df
# Out:
#     Name   Age     Dept  Salary
# 0  Alice  25.0       HR   55000
# 1    Bob  30.0       IT   65000
# 2  Carol  35.0  Finance   60000
# 3  David   NaN       HR   75000
# 4    Eva  29.0       IT   70000
# 5  Alice  25.0       HR   55000

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df['Age'].mean()
# Out:
# np.float64(28.8)

# %%
df
# Out:
#     Name   Age     Dept  Salary
# 0  Alice  25.0       HR   55000
# 1    Bob  30.0       IT   65000
# 2  Carol  35.0  Finance   60000
# 3  David   NaN       HR   75000
# 4    Eva  29.0       IT   70000
# 5  Alice  25.0       HR   55000

# %%
#forward fill and backward fill
df['Age'].fillna(method='ffill')
# Out:
# /tmp/ipython-input-3988860889.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method='ffill')
# 0    25.0
# 1    30.0
# 2    35.0
# 3    35.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(method='bfill')
# Out:
# /tmp/ipython-input-3224957626.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method='bfill')
# 0    25.0
# 1    30.0
# 2    35.0
# 3    29.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df
# Out:
#     Name   Age     Dept  Salary
# 0  Alice  25.0       HR   55000
# 1    Bob  30.0       IT   65000
# 2  Carol  35.0  Finance   60000
# 3  David   NaN       HR   75000
# 4    Eva  29.0       IT   70000
# 5  Alice  25.0       HR   55000

# %%
df["Name"]=df["Name"].replace("Eva","Eve")

# %%
df
# Out:
#     Name   Age     Dept  Salary
# 0  Alice  25.0       HR   55000
# 1    Bob  30.0       IT   65000
# 2  Carol  35.0  Finance   60000
# 3  David   NaN       HR   75000
# 4    Eve  29.0       IT   70000
# 5  Alice  25.0       HR   55000

# %%
df
# Out:
#     Name   Age     Dept  Salary
# 0  Alice  25.0       HR   55000
# 1    Bob  30.0       IT   65000
# 2  Carol  35.0  Finance   60000
# 3  David   NaN       HR   75000
# 4    Eve  29.0       IT   70000
# 5  Alice  25.0       HR   55000

# %%
df= df.drop_duplicates()

# %%
df
# Out:
#     Name   Age     Dept  Salary
# 0  Alice  25.0       HR   55000
# 1    Bob  30.0       IT   65000
# 2  Carol  35.0  Finance   60000
# 3  David   NaN       HR   75000
# 4    Eve  29.0       IT   70000

# %%
df=pd.read_csv('data.csv')

# %%
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
})

df.insert(1, 'D', [10, 11, 12])

print(df)
# Out:
#    A   D  B  C
# 0  1  10  4  7
# 1  2  11  5  8
# 2  3  12  6  9

# %% [markdown]
# Data Cleaning and Preprocessing
#
# *   -Handling missing data (using fillna, dropna).
# *   Data type conversions (using astype)
# *   Renaming columns and reindexing
# *   Filtering data based on conditions.

# %%
import pandas as pd
import numpy as np
data = {
    'A': [1, 2, np.nan, 4],
    'B': [5, np.nan, np.nan, 8],
    'C': [10, 11, 12, 13]
}
df = pd.DataFrame(data)

# %%
df_fill=df.fillna(1)

# %%
#forward/backward fillna
df_ffill=df.fillna(method='ffill')
df_bfill=df.fillna(method='bfill')

# %%
data = {
    'A': [1, 2, np.nan, 4],
    'B': [5, np.nan, np.nan, 8],
    'C': [10, 11, 12, 13]
}
df=pd.DataFrame(data)

# %%
df_droprow=df.dropna()

# %%
df_dropcol=df.dropna(axis=1)

# %%
data = {'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [7, 8, 9]}
df=pd.DataFrame(data)
df_renamed=df.rename(columns={'col1':'A','col2':'B','col3':'C'})

# %%
#Filtering data based on conditions.
import pandas as pd

# Sample data
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [24, 17, 50, 33, 29],
    'Salary': [70000, 48000, 110000, 95000, 65000]
}
df=pd.DataFrame(data)

# %%
# Filter for Age > 30

# %%
# Filter for Age > 25 and Salary > 90000

# %% [markdown]
# Group by and aggregate

# %%
data = {
    'Department': ['Sales', 'Marketing', 'IT', 'HR', 'Sales', 'IT'],
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
    'Salary': [70000, 48000, 110000, 50000, 72000, 95000]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)

# %%
# Group by 'Department'

# %%
# Calculate mean salary per department

# %%
# Calculate total salary per department

# %%
# Applying multiple aggregation functions

# %%
# Group by multiple columns

# %%
import pandas as pd
df1 = pd.DataFrame({'ID':[1,2,3,5,9],
                    'Col_1':[1,2,3,4,5],
                    'Col_2':[6,7,8,9,10],
                    'Col_3':[11,12,13,14,15],
                    'Col_4':['apple','orange','banana','strawberry','raspberry']
                   })

df2 = pd.DataFrame({'ID':[1,1,3,5],
                    'Col_A':[8,9,10,11],
                    'Col_B':[12,13,15,17],
                    'Col_4':['apple','orange','banana','kiwi']
                   })

# %%
#inner

# %%
#on

# %%
#on-multiple columns

# %%
#adding suffix and joining of separate columns

# %%
#types of joins- Inner, Outer, Left, Right

#Left Join
