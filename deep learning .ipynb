# %% [markdown]
# <a href="https://colab.research.google.com/github/sush0037/my-portfolio/blob/master/deep%20learning%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Artificial Neural Network
>>

Recurrent Neural Network
>>
mlp >> multilayer perceptron
cnn >> convolutional neural network
rnn >> recurrent neural network

inputs >> weights >> trasnfer function (aggregate) >> activation function

weights need >> Weights are essential in MLPs because they determine the strength of the connection between neurons.
