# %% [markdown]
# <a href="https://colab.research.google.com/github/sush0037/my-portfolio/blob/master/Engaging_with_genAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GenAI  >> llm and GAN (AE + VAE)
#
# llm tools jasper, compose AI (chrome extension)
# hyperwrite
# copy ai
# lavender
# lex
# lyka
# chatpgpt
# notion.ai
# notebook lm
# gemini
# read ai
# fireflies
# academia
# consensus
# storm
# synthesia
# gallectia
#
# prompts >> strategies, llm settings (temperatrue, tokens, top-p, top-k) , components
#
# instruction,
# context,
# example,
# output format,
# role and tone
#
# zero shot,few shot, Chain of thought, ToT, ReAct >> reduce hallucination
#
# how do we treat hallucination
# >> fine tuning and RAG
# RAG based models
#
# GAN >> GENERATIVE ADVERSERIAL NETWORK
# DCGAN
# STYLE GAN
# SR GAN
#
# THISPERSONNOTEXIST website
#
# architectual GAN
#
# Generator discrimanator (define real and fake)
# nano banana
# diffusion model
#
# autoencoders
# variation auto encoders
#
# stabled defusion hugging facce
# hugging face website medium
#
# diffusion models : DALL-E 2, Midjourney, and Stable Diffusion
# midjourney
#
#
# imagenet >> source of images with diffusion set
#
# unsplash.com
#
# runway ml2
#
# sora
